# %% [markdown]
# ## Correlation Background:
# You are given data on the SAT scores from the correlation exercise:

# %%
write = [344,383,611,713,536]
read = [378,349,503,719,503]
mean_w = 517
rean_r = 490
cov = 21155.55

# %%
import seaborn as sbn
w_scartter = sbn.scatterplot(x=write, y=read)
print(w_scartter)
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
r_scartter = sbn.scatterplot(x=read, y=write)
print(r_scartter)
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Task 1:
# Calculate the correlation coefficient of the two datasets.

# %%
import statistics as st

corr = st.correlation(write, read)
print(corr)
# Out:
# 0.9381257133317581

# %% [markdown]
# ## Task 2:
# Comment on the strength of the correlation between the two datasets
#
# # R:
# The correlation coefficient is very close to be equal to 1, this means that there is a strong and positive correlation between this two datasets.
