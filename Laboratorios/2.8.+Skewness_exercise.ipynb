# %% [markdown]
# # Skewness_exercise Background:
# You are given two datasets:

# %%
Data_set1 = [212,869,220,654,511,624,420,121,428,865,799,405,230,670,870,366,99,55,489,312,493,163,221,84,144,48,375,86,168,100]

Data_set2 = [586,760,495,678,559,415,370,659,119,288,241,787,522,207,160,526,656,848,720,676,581,929,653,661,770,800,529,975,995,947]

# %% [markdown]
# ## Task 1:
# Identify the skewness of dataset 1. You may use the formula from the lesson, the skewness formula in excel (=SKEW) or you can plot it on a graph:

# %%
import pandas as pd
import seaborn as sbn

df_data1 = pd.Series(Data_set1)
skew1 = df_data1.skew()
sbn.displot(df_data1)
print(skew1)
# Out:
# 0.6309880119650573

# %% [markdown]
# ## Task 2:
# Identify the skewness of dataset 2. You may use the formula from the lesson, the skewness formula in excel (=SKEW) or you can plot it on a graph:

# %%
df_data2 = pd.Series(Data_set2)
skew2 = df_data2.skew()
sbn.displot(df_data2)
print(skew2)
# Out:
# -0.37064131089909286
